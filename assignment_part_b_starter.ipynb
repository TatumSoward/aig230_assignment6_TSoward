# %% [markdown]
# <a href="https://colab.research.google.com/github/TatumSoward/aig230_assignment6_TSoward/blob/main/assignment_part_b_starter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AIG230 – Assignment 6 (Part B Starter Notebook)
# ## Neural Language Model with PyTorch (RNN) – Student Version
#
# This notebook covers **all of Part B**:
#
# - **B1** Numericalization + training examples
# - **B2** Build an RNN Language Model
# - **B3** Train + validate (loss + perplexity)
# - **B4** Test perplexity + text generation
#
# ### Dataset (same as Part A)
# - **NLTK Brown corpus**, category: `news`
#
# ### Important
# This is a **starter notebook**. You must complete the **TODO** blocks.
# Do not delete TODO comments. Add your code underneath them.

# %%
# ===== 1) Setup =====
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

import re
import math
import random
from collections import Counter
from dataclasses import dataclass
from typing import List, Dict, Tuple

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

import nltk
from nltk.corpus import brown

# Download if needed (safe to run multiple times)
nltk.download('brown')

# Reproducibility (optional)
random.seed(42)
torch.manual_seed(42)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)
# Out:
# Device: cuda
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!

# %%
# ===== 2) Configuration (edit if needed) =====
# You can edit these hyperparameters as needed. The defaults should work for a basic run.
# This are not fixed rules, just a starting point. Feel free to experiment with different values!
# This parameter class is just a convenient way to store all the settings in one place. You can also use a dictionary or command-line arguments if you prefer.
# These parameters define the dataset category, how to split the data, vocabulary cutoff, model architecture, and training settings. Adjusting these can affect the performance and training time of your model.
@dataclass
class Config:
    category: str = "news"
    train_ratio: float = 0.80
    val_ratio: float = 0.10
    test_ratio: float = 0.10

    min_freq: int = 2       # vocab cutoff (train only)
    seq_len: int = 30       # T
    batch_size: int = 512 # Changed from 32 b/c GPU was not taking over from CPU in Colab

    emb_dim: int = 128
    hid_dim: int = 256
    num_layers: int = 1
    dropout: float = 0.0    # use 0.0 if num_layers == 1

    lr: float = 1e-3
    epochs: int = 5
    grad_clip: float = 1.0  # optional but recommended

cfg = Config()

SPECIAL = {"BOS": "<bos>", "EOS": "<eos>", "UNK": "<unk>"}

# %% [markdown]
# # 3) Load + preprocess Brown (shared rules)
#
# Preprocessing rules:
# - lowercase
# - remove punctuation-only tokens
# - keep stopwords
# - add `<bos>` and `<eos>` to each sentence

# %%
# ===== 3) Load Brown sentences =====
# This section loads the raw sentences from the Brown corpus, preprocesses them by lowercasing and removing punctuation-only tokens, and adds special tokens for the beginning and end of sentences. The resulting `sents` variable is a list of tokenized sentences ready for building the vocabulary and training the model.
raw_sents: List[List[str]] = brown.sents(categories=cfg.category)
print("Raw sentences:", len(raw_sents))
print("Example raw:", raw_sents[0][:20])

_punct_only = re.compile(r"^\W+$")

def preprocess_sentence(tokens: List[str]) -> List[str]:
    out = []
    for tok in tokens:
        tok = tok.lower()
        if _punct_only.match(tok):
            continue
        out.append(tok)
    return [SPECIAL["BOS"], *out, SPECIAL["EOS"]]

sents = [preprocess_sentence(s) for s in raw_sents]
print("Example preprocessed:", sents[0][:25])
# Out:
# Raw sentences: 4623
# Example raw: ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', 'Friday', 'an', 'investigation', 'of', "Atlanta's", 'recent', 'primary', 'election', 'produced', '``', 'no', 'evidence', "''", 'that']
# Example preprocessed: ['<bos>', 'the', 'fulton', 'county', 'grand', 'jury', 'said', 'friday', 'an', 'investigation', 'of', "atlanta's", 'recent', 'primary', 'election', 'produced', 'no', 'evidence', 'that', 'any', 'irregularities', 'took', 'place', '<eos>']

# %% [markdown]
# # 4) Split train/val/test (by sentence)
#
# Split by sentence to avoid leakage.

# %%
# ===== 4) Split =====
# This section splits the preprocessed sentences into training, validation, and test sets based on the specified ratios in the configuration. It also defines a helper function to count the total number of tokens in each split and prints out the number of sentences and tokens for each set.
n = len(sents)
n_train = int(cfg.train_ratio * n)
n_val = int(cfg.val_ratio * n)
n_test = n - n_train - n_val

train_sents = sents[:n_train]
val_sents = sents[n_train:n_train+n_val]
test_sents = sents[n_train+n_val:]

def num_tokens(slist: List[List[str]]) -> int:
    return sum(len(s) for s in slist)

print("Train:", len(train_sents), "sentences |", num_tokens(train_sents), "tokens")
print("Val  :", len(val_sents),   "sentences |", num_tokens(val_sents),   "tokens")
print("Test :", len(test_sents),  "sentences |", num_tokens(test_sents),  "tokens")
# Out:
# Train: 3698 sentences | 77918 tokens
# Val  : 462 sentences | 10264 tokens
# Test : 463 sentences | 9656 tokens

# %% [markdown]
# # 5) Build vocabulary (train only)
#
# Words with frequency `< min_freq` become `<unk>`.

# %%
# ===== 5) Vocabulary =====
# This section builds the vocabulary from the training sentences by counting the frequency of each token and including only those that meet the minimum frequency threshold specified in the configuration.
# It also creates mappings from tokens to indices (`stoi`) and from indices to tokens (`itos`), and prints out some statistics about the vocabulary and the most common tokens in the training set.
train_tokens = [tok for sent in train_sents for tok in sent]
counts = Counter(train_tokens)

itos = [SPECIAL["BOS"], SPECIAL["EOS"], SPECIAL["UNK"]]
stoi: Dict[str, int] = {tok: i for i, tok in enumerate(itos)}

for tok, c in counts.most_common():
    if tok in stoi:
        continue
    if c >= cfg.min_freq:
        stoi[tok] = len(itos)
        itos.append(tok)

vocab_size = len(itos)
unk_id = stoi[SPECIAL["UNK"]]

print("min_freq:", cfg.min_freq)
print("vocab_size:", vocab_size)
print("UNK id:", unk_id)
print("\nTop 15 tokens (train):")
for tok, c in counts.most_common(15):
    print(f"{tok:>12}  {c}")
# Out:
# min_freq: 2
# vocab_size: 5353
# UNK id: 2
#
# Top 15 tokens (train):
#          the  5072
#        <bos>  3698
#        <eos>  3698
#           of  2321
#          and  1740
#            a  1710
#           to  1649
#           in  1592
#          for  787
#         that  644
#           is  575
#          was  566
#           on  538
#           at  531
#           he  509

# %% [markdown]
# # 6) B1 – Numericalize + create training examples (Option 1)
#
# You will:
# 1) Convert each sentence into token IDs
# 2) Concatenate into one long stream per split
# 3) Build a Dataset that returns:
# - `x = stream[i : i+T]`
# - `y = stream[i+1 : i+T+1]`
#
# Complete the TODO blocks below.

# %%
# ===== 6.1) Numericalize (TODO) =====
# This function converts a list of tokens into a list of corresponding token IDs using the `stoi` mapping.
# If a token is not found in the vocabulary, it uses the `unk_id` to represent it. This step is essential for preparing the data to be fed into the model, as models typically work with numerical representations of text.
# Why this is neccessary? Models cannot process raw text; they require numerical input. By converting tokens to their corresponding IDs, we can efficiently represent the text data in a format suitable for training neural networks. This also allows us to handle out-of-vocabulary tokens gracefully using the `unk_id`.
# How this connect to the embedding layer? The embedding layer takes token IDs as input and maps them to dense vector representations (embeddings).
# By numericalizing the sentences, we can feed these token IDs into the embedding layer, which will then produce the corresponding embeddings for each token. This is a crucial step in the pipeline, as it allows us to convert raw text into a format that can be processed by the neural network.

def numericalize_sentence(tokens: List[str], stoi: Dict[str, int], unk_id: int) -> List[int]:
    # TODO: return list of token IDs for this sentence
    # Hint: use stoi.get(tok, unk_id)
    token_ids = [stoi.get(tok, unk_id) for tok in tokens] # looks for tok in stoi dict and returns unk_id if not present
    return token_ids

train_ids_sents = [numericalize_sentence(s, stoi, unk_id) for s in train_sents]
val_ids_sents   = [numericalize_sentence(s, stoi, unk_id) for s in val_sents]
test_ids_sents  = [numericalize_sentence(s, stoi, unk_id) for s in test_sents]

print("Example tokens:", train_sents[0][:12])
print("Example ids   :", train_ids_sents[0][:12])
# Out:
# Example tokens: ['<bos>', 'the', 'fulton', 'county', 'grand', 'jury', 'said', 'friday', 'an', 'investigation', 'of', "atlanta's"]
# Example ids   : [0, 3, 603, 115, 451, 145, 20, 190, 29, 886, 4, 3528]

# %%
# ===== 6.2) Build streams =====
train_stream = [tid for sent in train_ids_sents for tid in sent]
val_stream   = [tid for sent in val_ids_sents   for tid in sent]
test_stream  = [tid for sent in test_ids_sents  for tid in sent]

print("Train stream length:", len(train_stream))
print("Val   stream length:", len(val_stream))
print("Test  stream length:", len(test_stream))
# Out:
# Train stream length: 77918
# Val   stream length: 10264
# Test  stream length: 9656

# %%
# ===== 6.3) Dataset (TODO) =====
class NextTokenStreamDataset(Dataset):
    def __init__(self, token_stream: List[int], seq_len: int):
        self.stream = token_stream
        self.T = seq_len

    def __len__(self) -> int:
        # TODO: return number of examples in this stream
        # Need T tokens for x and 1 extra token for y shift.
        return len(self.stream) - self.T

    def __getitem__(self, idx: int) -> Tuple[torch.Tensor, torch.Tensor]:
        # TODO: create x and y slices, convert to torch.long tensors
        stream = torch.tensor(self.stream, dtype=torch.long)
        # x: stream[idx : idx+T]
        x = stream[idx : idx+self.T]
        # y: stream[idx+1 : idx+T+1]
        y = stream[idx+1 : idx+self.T+1]
        return tuple((x, y))

train_ds = NextTokenStreamDataset(train_stream, cfg.seq_len)
val_ds   = NextTokenStreamDataset(val_stream,   cfg.seq_len)
test_ds  = NextTokenStreamDataset(test_stream,  cfg.seq_len)

print("Train examples:", len(train_ds))
# Out:
# Train examples: 77888

# %%
# ===== 6.4) DataLoaders + sanity check (run after TODOs are done) =====
train_loader = DataLoader(train_ds, batch_size=cfg.batch_size, shuffle=True, drop_last=True, num_workers=0, pin_memory=True)
val_loader   = DataLoader(val_ds,   batch_size=cfg.batch_size, shuffle=False, drop_last=True, num_workers=0, pin_memory=True)
test_loader  = DataLoader(test_ds,  batch_size=cfg.batch_size, shuffle=False, drop_last=True, num_workers=0, pin_memory=True)

x_batch, y_batch = next(iter(train_loader))
print("x_batch shape:", x_batch.shape)  # expected: (B, T)
print("y_batch shape:", y_batch.shape)  # expected: (B, T)
print("x_batch dtype:", x_batch.dtype)

print("First 10 x:", x_batch[0][:10].tolist())
print("First 10 y:", y_batch[0][:10].tolist())
# Out:
# x_batch shape: torch.Size([512, 30])
# y_batch shape: torch.Size([512, 30])
# x_batch dtype: torch.int64
# First 10 x: [2, 971, 5, 3127, 2, 398, 1, 0, 3, 1275]
# First 10 y: [971, 5, 3127, 2, 398, 1, 0, 3, 1275, 70]

# %% [markdown]
# # 7) B2 – Build the RNN Language Model
#
# Model requirements:
# - Embedding layer
# - RNN layer (`nn.RNN`)
# - Linear layer to vocab size
#
# Complete the TODO blocks.

# %%
# ===== 7) Model (TODO) =====
# Configuration class is defined at the top of the notebook. You can adjust the hyperparameters there as needed.
class RNNLanguageModel(nn.Module):
    def __init__(self, vocab_size: int, emb_dim: int, hid_dim: int, num_layers: int = 1, dropout: float = 0.0):
        super().__init__()
        # TODO: define embedding layer
        self.embedding = nn.Embedding(num_embeddings=vocab_size, embedding_dim=emb_dim)
        self.dropout = nn.Dropout(dropout)
        # TODO: define RNN layer (batch_first=True)
        self.rnn = nn.LSTM(input_size=emb_dim, hidden_size=hid_dim, dropout=dropout if num_layers>1 else 0, batch_first=True)
        # TODO: define output projection layer (hid_dim -> vocab_size)
        self.projection = nn.Linear(hid_dim, vocab_size)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # x: (B, T) token IDs
        # Return logits: (B, T, V) -> batch, time (seq length), vocab
        # TODO: embed -> rnn -> linear

        #1. Embedding Layer
        # Output shape: (B, T, emb_dim)
        out = self.embedding(x)
        #2. Dropout 1
        out = self.dropout(out)
        #3. RNN
        # We pass 'None' for the hidden state; PyTorch defaults to all zeros.
        # rnn_out: (B, T, hid_dim)
        out, _ = self.rnn(out, None)
        #2. Dropout 2
        out = self.dropout(out)
        #5. Projection
        # Maps hid_dim -> vocab_size (V)
        # logits shape: (B, T, V)
        return self.projection(out)

# Instantiate model (after TODOs)
model = RNNLanguageModel(
    vocab_size=vocab_size,
    emb_dim=cfg.emb_dim,
    hid_dim=cfg.hid_dim,
    num_layers=cfg.num_layers,
    dropout=cfg.dropout
).to(device)

# Parameter count
num_params = sum(p.numel() for p in model.parameters())
print("Model parameters:", num_params)
# Out:
# Model parameters: 2456169

# %% [markdown]
# # 8) B3 – Training + validation (loss + perplexity)
#
# You will:
# - Define loss (`CrossEntropyLoss`)
# - Train for several epochs
# - Compute validation perplexity
#
# Complete the TODO blocks.

# %%
# ===== 8.1) Loss + optimizer (TODO) =====
# For language modeling with logits of shape (B, T, V),
# CrossEntropyLoss expects (N, V) logits and (N,) targets.
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=cfg.lr)

print("Ready (criterion, optimizer):", criterion is not None, optimizer is not None)
# Out:
# Ready (criterion, optimizer): True True

# %%
# ===== 8.2) Helper: compute perplexity (TODO) =====
@torch.no_grad()
def evaluate_perplexity(model: nn.Module, loader: DataLoader) -> float:
    model.eval()
    total_loss = 0.0
    total_tokens = 0

    for x, y in loader:
        x = x.to(device)
        y = y.to(device)

        # TODO:
        # 1) logits = model(x) -> (B, T, V)
        logits = model(x)
        # 2) reshape logits to (B*T, V)
        logits = logits.view(-1, logits.size(-1))
        # 3) reshape y to (B*T,)
        y = y.view(-1)
        # 4) loss = criterion(...)
        loss = criterion(logits, y)
        # 5) accumulate total_loss weighted by number of tokens
        total_loss += loss
        total_tokens += y.numel()

    avg_loss = total_loss / max(total_tokens, 1)
    ppl = math.exp(avg_loss)
    return ppl

# %%
# ===== 8.3) Training loop (TODO) =====
from tqdm import tqdm
def train_one_epoch(model: nn.Module, loader: DataLoader) -> float:
    model.train()
    running_loss = 0.0
    running_tokens = 0

    # Wrap the loader in a progress bar
    pbar = tqdm(loader, desc="Training", unit="batch", leave=False)

    for x, y in pbar:
        x = x.to(device)
        y = y.to(device)

        # TODO:
        # 1) optimizer.zero_grad()
        optimizer.zero_grad()
        # 2) logits = model(x)
        logits = model(x)
        # 3) reshape logits/y for CrossEntropyLoss
        logits = logits.view(-1, logits.size(-1))
        y = y.view(-1)
        loss = criterion(logits, y)
        # 4) loss.backward()
        loss.backward()
        # 5) optional: clip gradients
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=0.5)
        # 6) optimizer.step()
        optimizer.step()
        # 7) accumulate running_loss weighted by number of tokens
        batch_loss_val = loss.item()
        num_tokens = y.numel()
        running_loss += batch_loss_val * num_tokens
        running_tokens += num_tokens

        # Update the bar's suffix with the current loss
        pbar.set_postfix(loss=f"{batch_loss_val:.4f}")

    return running_loss / max(running_tokens, 1)

# %%
print(f"Total batches to process: {len(train_loader)}")
# Out:
# Total batches to process: 152

# %%
train_losses = []
val_ppls = []

print(next(model.parameters()).is_cuda)
for epoch in range(1, cfg.epochs + 1):
    train_loss = train_one_epoch(model, train_loader)
    print("epoch trained")
    val_ppl = evaluate_perplexity(model, val_loader)
    print("perplexity calculated")

    train_losses.append(train_loss)
    val_ppls.append(val_ppl)

    print(f"Epoch {epoch:02d} | train loss: {train_loss:.4f} | val ppl: {val_ppl:.2f}")
# Out:
# True
# Training:   0%|          | 0/152 [00:00<?, ?batch/s]
# Training:   0%|          | 0/152 [00:06<?, ?batch/s, loss=6.2217]
# Training:   1%|          | 1/152 [00:06<16:31,  6.57s/batch, loss=6.2217]
# Training:   1%|          | 1/152 [00:12<16:31,  6.57s/batch, loss=6.2088]
# Training:   1%|▏         | 2/152 [00:12<14:54,  5.97s/batch, loss=6.2088]
# Training:   1%|▏         | 2/152 [00:14<14:54,  5.97s/batch, loss=6.2345]
# Training:   2%|▏         | 3/152 [00:14<11:15,  4.53s/batch, loss=6.2345]
# Training:   2%|▏         | 3/152 [00:17<11:15,  4.53s/batch, loss=6.1509]
# Training:   3%|▎         | 4/152 [00:17<09:30,  3.86s/batch, loss=6.1509]
# Training:   3%|▎         | 4/152 [00:21<09:30,  3.86s/batch, loss=6.2136]
# Training:   3%|▎         | 5/152 [00:21<09:06,  3.72s/batch, loss=6.2136]
# Training:   3%|▎         | 5/152 [00:24<09:06,  3.72s/batch, loss=6.1884]
# Training:   4%|▍         | 6/152 [00:24<08:42,  3.58s/batch, loss=6.1884]
# Training:   4%|▍         | 6/152 [00:27<08:42,  3.58s/batch, loss=6.1497]
# Training:   5%|▍         | 7/152 [00:27<08:00,  3.32s/batch, loss=6.1497]
# Training:   5%|▍         | 7/152 [00:30<08:00,  3.32s/batch, loss=6.1717]
# Training:   5%|▌         | 8/152 [00:30<07:33,  3.15s/batch, loss=6.1717]
# Training:   5%|▌         | 8/152 [00:34<07:33,  3.15s/batch, loss=6.1640]
# Training:   6%|▌         | 9/152 [00:34<08:09,  3.42s/batch, loss=6.1640]
# Training:   6%|▌         | 9/152 [00:37<08:09,  3.42s/batch, loss=6.1304]
# Training:   7%|▋         | 10/152 [00:37<07:52,  3.33s/batch, loss=6.1304]
# Training:   7%|▋         | 10/152 [00:40<07:52,  3.33s/batch, loss=6.0933]
# Training:   7%|▋         | 11/152 [00:40<07:26,  3.16s/batch, loss=6.0933]
# Training:   7%|▋         | 11/152 [00:42<07:26,  3.16s/batch, loss=6.1258]
# Training:   8%|▊         | 12/152 [00:42<07:09,  3.07s/batch, loss=6.1258]
# Training:   8%|▊         | 12/152 [00:46<07:09,  3.07s/batch, loss=6.0794]
# Training:   9%|▊         | 13/152 [00:46<07:25,  3.21s/batch, loss=6.0794]
# Training:   9%|▊         | 13/152 [00:49<07:25,  3.21s/batch, loss=6.0575]
# Training:   9%|▉         | 14/152 [00:49<07:24,  3.22s/batch, loss=6.0575]
# Training:   9%|▉         | 14/152 [00:52<07:24,  3.22s/batch, loss=6.0653]
# Training:  10%|▉         | 15/152 [00:52<07:04,  3.10s/batch, loss=6.0653]
# Training:  10%|▉         | 15/152 [00:55<07:04,  3.10s/batch, loss=6.0585]
# Training:  11%|█         | 16/152 [00:55<06:48,  3.00s/batch, loss=6.0585]
# Training:  11%|█         | 16/152 [00:58<06:48,  3.00s/batch, loss=6.0508]
# Training:  11%|█         | 17/152 [00:58<06:58,  3.10s/batch, loss=6.0508]
# Training:  11%|█         | 17/152 [01:02<06:58,  3.10s/batch, loss=6.0506]
# Training:  12%|█▏        | 18/152 [01:02<07:10,  3.21s/batch, loss=6.0506]
# Training:  12%|█▏        | 18/152 [01:04<07:10,  3.21s/batch, loss=6.0393]
# Training:  12%|█▎        | 19/152 [01:04<06:50,  3.09s/batch, loss=6.0393]
# Training:  12%|█▎        | 19/152 [01:07<06:50,  3.09s/batch, loss=6.0257]
# Training:  13%|█▎        | 20/152 [01:07<06:34,  2.99s/batch, loss=6.0257]
# Training:  13%|█▎        | 20/152 [01:10<06:34,  2.99s/batch, loss=5.9945]
# Training:  14%|█▍        | 21/152 [01:10<06:36,  3.03s/batch, loss=5.9945]
# Training:  14%|█▍        | 21/152 [01:14<06:36,  3.03s/batch, loss=6.0371]
# Training:  14%|█▍        | 22/152 [01:14<06:55,  3.20s/batch, loss=6.0371]
# Training:  14%|█▍        | 22/152 [01:17<06:55,  3.20s/batch, loss=6.0033]
# Training:  15%|█▌        | 23/152 [01:17<06:37,  3.08s/batch, loss=6.0033]
# Training:  15%|█▌        | 23/152 [01:19<06:37,  3.08s/batch, loss=6.0206]
# Training:  16%|█▌        | 24/152 [01:19<06:22,  2.98s/batch, loss=6.0206]
# Training:  16%|█▌        | 24/152 [01:22<06:22,  2.98s/batch, loss=6.0232]
# Training:  16%|█▋        | 25/152 [01:22<06:22,  3.01s/batch, loss=6.0232]
# Training:  16%|█▋        | 25/152 [01:26<06:22,  3.01s/batch, loss=5.9873]
# Training:  17%|█▋        | 26/152 [01:26<06:48,  3.24s/batch, loss=5.9873]
# Training:  17%|█▋        | 26/152 [01:29<06:48,  3.24s/batch, loss=5.9788]
# Training:  18%|█▊        | 27/152 [01:29<06:27,  3.10s/batch, loss=5.9788]
# Training:  18%|█▊        | 27/152 [01:32<06:27,  3.10s/batch, loss=5.9783]
# Training:  18%|█▊        | 28/152 [01:32<06:12,  3.00s/batch, loss=5.9783]
# Training:  18%|█▊        | 28/152 [01:35<06:12,  3.00s/batch, loss=5.9858]
# Training:  19%|█▉        | 29/152 [01:35<06:04,  2.97s/batch, loss=5.9858]
# Training:  19%|█▉        | 29/152 [01:39<06:04,  2.97s/batch, loss=5.9399]
# Training:  20%|█▉        | 30/152 [01:39<06:36,  3.25s/batch, loss=5.9399]
# Training:  20%|█▉        | 30/152 [01:42<06:36,  3.25s/batch, loss=5.9321]
# Training:  20%|██        | 31/152 [01:42<06:55,  3.43s/batch, loss=5.9321]
# Training:  20%|██        | 31/152 [01:45<06:55,  3.43s/batch, loss=5.9490]
# Training:  21%|██        | 32/152 [01:45<06:28,  3.24s/batch, loss=5.9490]
# Training:  21%|██        | 32/152 [01:49<06:28,  3.24s/batch, loss=5.9631]
# Training:  22%|██▏       | 33/152 [01:49<06:42,  3.39s/batch, loss=5.9631]
# Training:  22%|██▏       | 33/152 [01:52<06:42,  3.39s/batch, loss=5.9242]
# Training:  22%|██▏       | 34/152 [01:52<06:26,  3.28s/batch, loss=5.9242]
# Training:  22%|██▏       | 34/152 [01:55<06:26,  3.28s/batch, loss=5.9329]
# Training:  23%|██▎       | 35/152 [01:55<06:04,  3.12s/batch, loss=5.9329]
# Training:  23%|██▎       | 35/152 [01:58<06:04,  3.12s/batch, loss=5.8928]
# Training:  24%|██▎       | 36/152 [01:58<05:49,  3.02s/batch, loss=5.8928]
# Training:  24%|██▎       | 36/152 [02:01<05:49,  3.02s/batch, loss=5.9012]
# Training:  24%|██▍       | 37/152 [02:01<06:03,  3.16s/batch, loss=5.9012]
# Training:  24%|██▍       | 37/152 [02:04<06:03,  3.16s/batch, loss=5.8746]
# Training:  25%|██▌       | 38/152 [02:04<06:05,  3.21s/batch, loss=5.8746]
# Training:  25%|██▌       | 38/152 [02:07<06:05,  3.21s/batch, loss=5.9313]
# Training:  26%|██▌       | 39/152 [02:07<05:47,  3.08s/batch, loss=5.9313]
# Training:  26%|██▌       | 39/152 [02:10<05:47,  3.08s/batch, loss=5.9001]
# Training:  26%|██▋       | 40/152 [02:10<05:33,  2.98s/batch, loss=5.9001]
# Training:  26%|██▋       | 40/152 [02:13<05:33,  2.98s/batch, loss=5.9022]
# Training:  27%|██▋       | 41/152 [02:13<05:40,  3.06s/batch, loss=5.9022]
# Training:  27%|██▋       | 41/152 [02:17<05:40,  3.06s/batch, loss=5.8639]
# Training:  28%|██▊       | 42/152 [02:17<05:52,  3.20s/batch, loss=5.8639]
# Training:  28%|██▊       | 42/152 [02:19<05:52,  3.20s/batch, loss=5.8951]
# Training:  28%|██▊       | 43/152 [02:19<05:35,  3.08s/batch, loss=5.8951]
# Training:  28%|██▊       | 43/152 [02:22<05:35,  3.08s/batch, loss=5.9552]
# Training:  29%|██▉       | 44/152 [02:22<05:22,  2.98s/batch, loss=5.9552]
# Training:  29%|██▉       | 44/152 [02:25<05:22,  2.98s/batch, loss=5.8384]
# Training:  30%|██▉       | 45/152 [02:25<05:21,  3.00s/batch, loss=5.8384]
# Training:  30%|██▉       | 45/152 [02:29<05:21,  3.00s/batch, loss=5.8404]
# Training:  30%|███       | 46/152 [02:29<05:44,  3.25s/batch, loss=5.8404]
# Training:  30%|███       | 46/152 [02:32<05:44,  3.25s/batch, loss=5.8161]
# Training:  31%|███       | 47/152 [02:32<05:26,  3.11s/batch, loss=5.8161]
# Training:  31%|███       | 47/152 [02:35<05:26,  3.11s/batch, loss=5.8235]
# Training:  32%|███▏      | 48/152 [02:35<05:13,  3.02s/batch, loss=5.8235]
# Training:  32%|███▏      | 48/152 [02:38<05:13,  3.02s/batch, loss=5.8420]
# Training:  32%|███▏      | 49/152 [02:38<05:06,  2.97s/batch, loss=5.8420]
# Training:  32%|███▏      | 49/152 [02:41<05:06,  2.97s/batch, loss=5.7980]
# Training:  33%|███▎      | 50/152 [02:41<05:32,  3.26s/batch, loss=5.7980]
# Training:  33%|███▎      | 50/152 [02:44<05:32,  3.26s/batch, loss=5.8431]
# Training:  34%|███▎      | 51/152 [02:44<05:16,  3.14s/batch, loss=5.8431]
# Training:  34%|███▎      | 51/152 [02:47<05:16,  3.14s/batch, loss=5.7893]
# Training:  34%|███▍      | 52/152 [02:47<05:06,  3.06s/batch, loss=5.7893]
# Training:  34%|███▍      | 52/152 [02:50<05:06,  3.06s/batch, loss=5.7987]
# Training:  35%|███▍      | 53/152 [02:50<04:58,  3.01s/batch, loss=5.7987]
# Training:  35%|███▍      | 53/152 [02:54<04:58,  3.01s/batch, loss=5.7801]
# Training:  36%|███▌      | 54/152 [02:54<05:23,  3.30s/batch, loss=5.7801]
# Training:  36%|███▌      | 54/152 [02:57<05:23,  3.30s/batch, loss=5.7757]
# Training:  36%|███▌      | 55/152 [02:57<05:06,  3.16s/batch, loss=5.7757]
# Training:  36%|███▌      | 55/152 [03:00<05:06,  3.16s/batch, loss=5.7950]
# Training:  37%|███▋      | 56/152 [03:00<04:52,  3.05s/batch, loss=5.7950]
# Training:  37%|███▋      | 56/152 [03:02<04:52,  3.05s/batch, loss=5.7935]
# Training:  38%|███▊      | 57/152 [03:02<04:42,  2.97s/batch, loss=5.7935]
# Training:  38%|███▊      | 57/152 [03:06<04:42,  2.97s/batch, loss=5.7955]
# Training:  38%|███▊      | 58/152 [03:07<05:09,  3.29s/batch, loss=5.7955]
# Training:  38%|███▊      | 58/152 [03:09<05:09,  3.29s/batch, loss=5.7627]
# Training:  39%|███▉      | 59/152 [03:09<04:52,  3.15s/batch, loss=5.7627]
# Training:  39%|███▉      | 59/152 [03:12<04:52,  3.15s/batch, loss=5.7427]
# Training:  39%|███▉      | 60/152 [03:12<04:40,  3.05s/batch, loss=5.7427]
# Training:  39%|███▉      | 60/152 [03:15<04:40,  3.05s/batch, loss=5.7742]
# Training:  40%|████      | 61/152 [03:15<04:30,  2.97s/batch, loss=5.7742]
# Training:  40%|████      | 61/152 [03:19<04:30,  2.97s/batch, loss=5.7837]
# Training:  41%|████      | 62/152 [03:19<04:55,  3.28s/batch, loss=5.7837]
# Training:  41%|████      | 62/152 [03:22<04:55,  3.28s/batch, loss=5.7598]
# Training:  41%|████▏     | 63/152 [03:22<04:41,  3.16s/batch, loss=5.7598]
# Training:  41%|████▏     | 63/152 [03:25<04:41,  3.16s/batch, loss=5.7508]
# Training:  42%|████▏     | 64/152 [03:25<04:28,  3.05s/batch, loss=5.7508]
# Training:  42%|████▏     | 64/152 [03:27<04:28,  3.05s/batch, loss=5.7442]
# Training:  43%|████▎     | 65/152 [03:27<04:20,  3.00s/batch, loss=5.7442]
# Training:  43%|████▎     | 65/152 [03:32<04:20,  3.00s/batch, loss=5.7449]
# Training:  43%|████▎     | 66/152 [03:32<04:44,  3.31s/batch, loss=5.7449]
# Training:  43%|████▎     | 66/152 [03:34<04:44,  3.31s/batch, loss=5.7260]
# Training:  44%|████▍     | 67/152 [03:34<04:27,  3.15s/batch, loss=5.7260]
# Training:  44%|████▍     | 67/152 [03:37<04:27,  3.15s/batch, loss=5.6888]
# Training:  45%|████▍     | 68/152 [03:37<04:16,  3.05s/batch, loss=5.6888]
# Training:  45%|████▍     | 68/152 [03:40<04:16,  3.05s/batch, loss=5.6659]
# Training:  45%|████▌     | 69/152 [03:40<04:07,  2.98s/batch, loss=5.6659]
# Training:  45%|████▌     | 69/152 [03:44<04:07,  2.98s/batch, loss=5.7165]
# Training:  46%|████▌     | 70/152 [03:44<04:31,  3.30s/batch, loss=5.7165]
# Training:  46%|████▌     | 70/152 [03:47<04:31,  3.30s/batch, loss=5.6923]
# Training:  47%|████▋     | 71/152 [03:47<04:16,  3.17s/batch, loss=5.6923]
# Training:  47%|████▋     | 71/152 [03:50<04:16,  3.17s/batch, loss=5.6885]
# Training:  47%|████▋     | 72/152 [03:50<04:04,  3.05s/batch, loss=5.6885]
# Training:  47%|████▋     | 72/152 [03:52<04:04,  3.05s/batch, loss=5.6849]
# Training:  48%|████▊     | 73/152 [03:52<03:55,  2.98s/batch, loss=5.6849]
# Training:  48%|████▊     | 73/152 [03:56<03:55,  2.98s/batch, loss=5.6596]
# Training:  49%|████▊     | 74/152 [03:56<04:16,  3.29s/batch, loss=5.6596]
# Training:  49%|████▊     | 74/152 [03:59<04:16,  3.29s/batch, loss=5.6810]
# Training:  49%|████▉     | 75/152 [03:59<04:01,  3.14s/batch, loss=5.6810]
# Training:  49%|████▉     | 75/152 [04:02<04:01,  3.14s/batch, loss=5.6868]
# Training:  50%|█████     | 76/152 [04:02<03:50,  3.04s/batch, loss=5.6868]
# Training:  50%|█████     | 76/152 [04:05<03:50,  3.04s/batch, loss=5.6703]
# Training:  51%|█████     | 77/152 [04:05<03:41,  2.96s/batch, loss=5.6703]
# Training:  51%|█████     | 77/152 [04:09<03:41,  2.96s/batch, loss=5.6477]
# Training:  51%|█████▏    | 78/152 [04:09<04:03,  3.29s/batch, loss=5.6477]
# Training:  51%|█████▏    | 78/152 [04:12<04:03,  3.29s/batch, loss=5.6225]
# Training:  52%|█████▏    | 79/152 [04:12<03:49,  3.14s/batch, loss=5.6225]
# Training:  52%|█████▏    | 79/152 [04:14<03:49,  3.14s/batch, loss=5.6420]
# Training:  53%|█████▎    | 80/152 [04:14<03:38,  3.04s/batch, loss=5.6420]
# Training:  53%|█████▎    | 80/152 [04:17<03:38,  3.04s/batch, loss=5.6402]
# Training:  53%|█████▎    | 81/152 [04:17<03:32,  2.99s/batch, loss=5.6402]
# Training:  53%|█████▎    | 81/152 [04:21<03:32,  2.99s/batch, loss=5.6602]
# Training:  54%|█████▍    | 82/152 [04:21<03:52,  3.31s/batch, loss=5.6602]
# Training:  54%|█████▍    | 82/152 [04:24<03:52,  3.31s/batch, loss=5.6357]
# Training:  55%|█████▍    | 83/152 [04:24<03:38,  3.17s/batch, loss=5.6357]
# Training:  55%|█████▍    | 83/152 [04:27<03:38,  3.17s/batch, loss=5.5999]
# Training:  55%|█████▌    | 84/152 [04:27<03:27,  3.06s/batch, loss=5.5999]
# Training:  55%|█████▌    | 84/152 [04:30<03:27,  3.06s/batch, loss=5.6046]
# Training:  56%|█████▌    | 85/152 [04:30<03:19,  2.98s/batch, loss=5.6046]
# Training:  56%|█████▌    | 85/152 [04:34<03:19,  2.98s/batch, loss=5.5833]
# Training:  57%|█████▋    | 86/152 [04:34<03:38,  3.31s/batch, loss=5.5833]
# Training:  57%|█████▋    | 86/152 [04:37<03:38,  3.31s/batch, loss=5.6226]
# Training:  57%|█████▋    | 87/152 [04:37<03:26,  3.17s/batch, loss=5.6226]
# Training:  57%|█████▋    | 87/152 [04:40<03:26,  3.17s/batch, loss=5.5720]
# Training:  58%|█████▊    | 88/152 [04:40<03:16,  3.07s/batch, loss=5.5720]
# Training:  58%|█████▊    | 88/152 [04:42<03:16,  3.07s/batch, loss=5.5801]
# Training:  59%|█████▊    | 89/152 [04:42<03:09,  3.01s/batch, loss=5.5801]
# Training:  59%|█████▊    | 89/152 [04:47<03:09,  3.01s/batch, loss=5.5808]
# Training:  59%|█████▉    | 90/152 [04:47<03:27,  3.34s/batch, loss=5.5808]
# Training:  59%|█████▉    | 90/152 [04:49<03:27,  3.34s/batch, loss=5.5688]
# Training:  60%|█████▉    | 91/152 [04:49<03:14,  3.18s/batch, loss=5.5688]
# Training:  60%|█████▉    | 91/152 [04:52<03:14,  3.18s/batch, loss=5.5776]
# Training:  61%|██████    | 92/152 [04:52<03:04,  3.08s/batch, loss=5.5776]
# Training:  61%|██████    | 92/152 [04:55<03:04,  3.08s/batch, loss=5.5726]
# Training:  61%|██████    | 93/152 [04:55<02:58,  3.03s/batch, loss=5.5726]
# Training:  61%|██████    | 93/152 [04:59<02:58,  3.03s/batch, loss=5.5544]
# Training:  62%|██████▏   | 94/152 [04:59<03:15,  3.37s/batch, loss=5.5544]
# Training:  62%|██████▏   | 94/152 [05:02<03:15,  3.37s/batch, loss=5.5258]
# Training:  62%|██████▎   | 95/152 [05:02<03:02,  3.19s/batch, loss=5.5258]
# Training:  62%|██████▎   | 95/152 [05:05<03:02,  3.19s/batch, loss=5.5659]
# Training:  63%|██████▎   | 96/152 [05:05<02:51,  3.07s/batch, loss=5.5659]
# Training:  63%|██████▎   | 96/152 [05:08<02:51,  3.07s/batch, loss=5.5429]
# Training:  64%|██████▍   | 97/152 [05:08<02:43,  2.98s/batch, loss=5.5429]
# Training:  64%|██████▍   | 97/152 [05:12<02:43,  2.98s/batch, loss=5.5093]
# Training:  64%|██████▍   | 98/152 [05:12<03:01,  3.35s/batch, loss=5.5093]
# Training:  64%|██████▍   | 98/152 [05:15<03:01,  3.35s/batch, loss=5.5458]
# Training:  65%|██████▌   | 99/152 [05:15<02:50,  3.21s/batch, loss=5.5458]
# Training:  65%|██████▌   | 99/152 [05:18<02:50,  3.21s/batch, loss=5.5315]
# Training:  66%|██████▌   | 100/152 [05:18<02:40,  3.09s/batch, loss=5.5315]
# Training:  66%|██████▌   | 100/152 [05:20<02:40,  3.09s/batch, loss=5.5223]
# Training:  66%|██████▋   | 101/152 [05:20<02:32,  3.00s/batch, loss=5.5223]
# Training:  66%|██████▋   | 101/152 [05:24<02:32,  3.00s/batch, loss=5.5044]
# Training:  67%|██████▋   | 102/152 [05:24<02:45,  3.31s/batch, loss=5.5044]
# Training:  67%|██████▋   | 102/152 [05:27<02:45,  3.31s/batch, loss=5.4898]
# Training:  68%|██████▊   | 103/152 [05:27<02:34,  3.15s/batch, loss=5.4898]
# Training:  68%|██████▊   | 103/152 [05:30<02:34,  3.15s/batch, loss=5.5391]
# Training:  68%|██████▊   | 104/152 [05:30<02:25,  3.03s/batch, loss=5.5391]
# Training:  68%|██████▊   | 104/152 [05:33<02:25,  3.03s/batch, loss=5.5313]
# Training:  69%|██████▉   | 105/152 [05:33<02:18,  2.95s/batch, loss=5.5313]
# Training:  69%|██████▉   | 105/152 [05:37<02:18,  2.95s/batch, loss=5.4971]
# Training:  70%|██████▉   | 106/152 [05:37<02:30,  3.27s/batch, loss=5.4971]
# Training:  70%|██████▉   | 106/152 [05:39<02:30,  3.27s/batch, loss=5.4982]
# Training:  70%|███████   | 107/152 [05:39<02:20,  3.12s/batch, loss=5.4982]
# Training:  70%|███████   | 107/152 [05:42<02:20,  3.12s/batch, loss=5.4799]
# Training:  71%|███████   | 108/152 [05:42<02:13,  3.03s/batch, loss=5.4799]
# Training:  71%|███████   | 108/152 [05:45<02:13,  3.03s/batch, loss=5.4872]
# Training:  72%|███████▏  | 109/152 [05:45<02:07,  2.96s/batch, loss=5.4872]
# Training:  72%|███████▏  | 109/152 [05:49<02:07,  2.96s/batch, loss=5.4558]
# Training:  72%|███████▏  | 110/152 [05:49<02:19,  3.31s/batch, loss=5.4558]
# Training:  72%|███████▏  | 110/152 [05:52<02:19,  3.31s/batch, loss=5.4712]
# Training:   0%|          | 0/152 [19:07<?, ?batch/s, loss=6.7082]
#
# Training:  73%|███████▎  | 111/152 [05:55<02:10,  3.18s/batch, loss=5.4776]
# Training:  74%|███████▎  | 112/152 [05:55<02:05,  3.13s/batch, loss=5.4776]
# Training:  74%|███████▎  | 112/152 [05:58<02:05,  3.13s/batch, loss=5.4659]
# Training:  74%|███████▍  | 113/152 [05:58<01:58,  3.03s/batch, loss=5.4659]
# Training:  74%|███████▍  | 113/152 [06:02<01:58,  3.03s/batch, loss=5.4657]
# Training:  75%|███████▌  | 114/152 [06:02<02:07,  3.35s/batch, loss=5.4657]
# Training:  75%|███████▌  | 114/152 [06:05<02:07,  3.35s/batch, loss=5.4305]
# Training:  76%|███████▌  | 115/152 [06:05<01:57,  3.18s/batch, loss=5.4305]
# Training:  76%|███████▌  | 115/152 [06:08<01:57,  3.18s/batch, loss=5.4373]
# Training:  76%|███████▋  | 116/152 [06:08<01:50,  3.06s/batch, loss=5.4373]
# Training:  76%|███████▋  | 116/152 [06:10<01:50,  3.06s/batch, loss=5.4458]
# Training:  77%|███████▋  | 117/152 [06:10<01:43,  2.97s/batch, loss=5.4458]
# Training:  77%|███████▋  | 117/152 [06:14<01:43,  2.97s/batch, loss=5.4456]
# Training:  78%|███████▊  | 118/152 [06:14<01:53,  3.33s/batch, loss=5.4456]
# Training:  78%|███████▊  | 118/152 [06:17<01:53,  3.33s/batch, loss=5.4119]
# Training:  78%|███████▊  | 119/152 [06:17<01:44,  3.17s/batch, loss=5.4119]
# Training:  78%|███████▊  | 119/152 [06:20<01:44,  3.17s/batch, loss=5.4194]
# Training:  79%|███████▉  | 120/152 [06:20<01:37,  3.05s/batch, loss=5.4194]
# Training:  79%|███████▉  | 120/152 [06:23<01:37,  3.05s/batch, loss=5.3886]
# Training:  80%|███████▉  | 121/152 [06:23<01:31,  2.96s/batch, loss=5.3886]
# Training:  80%|███████▉  | 121/152 [06:27<01:31,  2.96s/batch, loss=5.4032]
# Training:  80%|████████  | 122/152 [06:27<01:38,  3.27s/batch, loss=5.4032]
# Training:  80%|████████  | 122/152 [06:30<01:38,  3.27s/batch, loss=5.4085]
# Training:  81%|████████  | 123/152 [06:30<01:30,  3.14s/batch, loss=5.4085]
# Training:  81%|████████  | 123/152 [06:32<01:30,  3.14s/batch, loss=5.4115]
# Training:  82%|████████▏ | 124/152 [06:32<01:24,  3.03s/batch, loss=5.4115]
# Training:  82%|████████▏ | 124/152 [06:35<01:24,  3.03s/batch, loss=5.3713]
# Training:  82%|████████▏ | 125/152 [06:35<01:20,  2.97s/batch, loss=5.3713]
# Training:  82%|████████▏ | 125/152 [06:39<01:20,  2.97s/batch, loss=5.3506]
# Training:  83%|████████▎ | 126/152 [06:39<01:25,  3.28s/batch, loss=5.3506]
# Training:  83%|████████▎ | 126/152 [06:42<01:25,  3.28s/batch, loss=5.3712]
# Training:  84%|████████▎ | 127/152 [06:42<01:18,  3.14s/batch, loss=5.3712]
# Training:  84%|████████▎ | 127/152 [06:45<01:18,  3.14s/batch, loss=5.3710]
# Training:  84%|████████▍ | 128/152 [06:45<01:13,  3.04s/batch, loss=5.3710]
# Training:  84%|████████▍ | 128/152 [06:48<01:13,  3.04s/batch, loss=5.3516]
# Training:  85%|████████▍ | 129/152 [06:48<01:08,  2.96s/batch, loss=5.3516]
# Training:  85%|████████▍ | 129/152 [06:52<01:08,  2.96s/batch, loss=5.3514]
# Training:  86%|████████▌ | 130/152 [06:52<01:12,  3.27s/batch, loss=5.3514]
# Training:  86%|████████▌ | 130/152 [06:55<01:12,  3.27s/batch, loss=5.3487]
# Training:  86%|████████▌ | 131/152 [06:55<01:06,  3.17s/batch, loss=5.3487]
# Training:  86%|████████▌ | 131/152 [06:57<01:06,  3.17s/batch, loss=5.3519]
# Training:  87%|████████▋ | 132/152 [06:57<01:01,  3.05s/batch, loss=5.3519]
# Training:  87%|████████▋ | 132/152 [07:00<01:01,  3.05s/batch, loss=5.3598]
# Training:  88%|████████▊ | 133/152 [07:00<00:56,  2.96s/batch, loss=5.3598]
# Training:  88%|████████▊ | 133/152 [07:04<00:56,  2.96s/batch, loss=5.3545]
# Training:  88%|████████▊ | 134/152 [07:04<00:59,  3.28s/batch, loss=5.3545]
# Training:  88%|████████▊ | 134/152 [07:07<00:59,  3.28s/batch, loss=5.3453]
# Training:  89%|████████▉ | 135/152 [07:07<00:53,  3.13s/batch, loss=5.3453]
# Training:  89%|████████▉ | 135/152 [07:10<00:53,  3.13s/batch, loss=5.3517]
# Training:  89%|████████▉ | 136/152 [07:10<00:48,  3.03s/batch, loss=5.3517]
# Training:  89%|████████▉ | 136/152 [07:12<00:48,  3.03s/batch, loss=5.3653]
# Training:  90%|█████████ | 137/152 [07:12<00:44,  2.96s/batch, loss=5.3653]
# Training:  90%|█████████ | 137/152 [07:17<00:44,  2.96s/batch, loss=5.3292]
# Training:  91%|█████████ | 138/152 [07:17<00:46,  3.31s/batch, loss=5.3292]
# Training:  91%|█████████ | 138/152 [07:19<00:46,  3.31s/batch, loss=5.3343]
# Training:  91%|█████████▏| 139/152 [07:19<00:41,  3.16s/batch, loss=5.3343]
# Training:  91%|█████████▏| 139/152 [07:22<00:41,  3.16s/batch, loss=5.3094]
# Training:  92%|█████████▏| 140/152 [07:22<00:36,  3.06s/batch, loss=5.3094]
# Training:  92%|█████████▏| 140/152 [07:25<00:36,  3.06s/batch, loss=5.3043]
# Training:  93%|█████████▎| 141/152 [07:25<00:32,  2.97s/batch, loss=5.3043]
# Training:  93%|█████████▎| 141/152 [07:29<00:32,  2.97s/batch, loss=5.3086]
# Training:  93%|█████████▎| 142/152 [07:29<00:33,  3.32s/batch, loss=5.3086]
# Training:  93%|█████████▎| 142/152 [07:32<00:33,  3.32s/batch, loss=5.3086]
# Training:  94%|█████████▍| 143/152 [07:32<00:28,  3.15s/batch, loss=5.3086]
# Training:  94%|█████████▍| 143/152 [07:35<00:28,  3.15s/batch, loss=5.3267]
# Training:  95%|█████████▍| 144/152 [07:35<00:24,  3.04s/batch, loss=5.3267]
# Training:  95%|█████████▍| 144/152 [07:37<00:24,  3.04s/batch, loss=5.2743]
# Training:  95%|█████████▌| 145/152 [07:37<00:20,  2.97s/batch, loss=5.2743]
# Training:  95%|█████████▌| 145/152 [07:42<00:20,  2.97s/batch, loss=5.2921]
# Training:  96%|█████████▌| 146/152 [07:42<00:19,  3.31s/batch, loss=5.2921]
# Training:  96%|█████████▌| 146/152 [07:44<00:19,  3.31s/batch, loss=5.3097]
# Training:  97%|█████████▋| 147/152 [07:44<00:15,  3.16s/batch, loss=5.3097]
# Training:  97%|█████████▋| 147/152 [07:47<00:15,  3.16s/batch, loss=5.2854]
# Training:  97%|█████████▋| 148/152 [07:47<00:12,  3.05s/batch, loss=5.2854]
# Training:  97%|█████████▋| 148/152 [07:50<00:12,  3.05s/batch, loss=5.3183]
# Training:  98%|█████████▊| 149/152 [07:50<00:09,  3.01s/batch, loss=5.3183]
# Training:  98%|█████████▊| 149/152 [07:54<00:09,  3.01s/batch, loss=5.2772]
# Training:  99%|█████████▊| 150/152 [07:54<00:06,  3.34s/batch, loss=5.2772]
# Training:  99%|█████████▊| 150/152 [07:57<00:06,  3.34s/batch, loss=5.2868]
# Training:  99%|█████████▉| 151/152 [07:57<00:03,  3.18s/batch, loss=5.2868]
# Training:  99%|█████████▉| 151/152 [08:00<00:03,  3.18s/batch, loss=5.2471]
# Training: 100%|██████████| 152/152 [08:00<00:00,  3.08s/batch, loss=5.2471]
# epoch trained
# perplexity calculated
# Epoch 01 | train loss: 5.6837 | val ppl: 1.00
# epoch trained
# perplexity calculated
# Epoch 02 | train loss: 4.9313 | val ppl: 1.00
# epoch trained
# perplexity calculated
# Epoch 03 | train loss: 4.3545 | val ppl: 1.00
# epoch trained
# perplexity calculated
# Epoch 04 | train loss: 3.8665 | val ppl: 1.00
# epoch trained
# perplexity calculated
# Epoch 05 | train loss: 3.4504 | val ppl: 1.00

# %%
# ===== 8.4) Plot training loss (optional) =====
import matplotlib.pyplot as plt

plt.figure()
plt.plot(range(1, len(train_losses)+1), train_losses)
plt.xlabel("Epoch")
plt.ylabel("Train Loss")
plt.title("Training Loss per Epoch")
plt.show()

# %% [markdown]
# # 9) B4 – Test perplexity + text generation
#
# You will:
# - Report test perplexity
# - Generate text by sampling from the model
#
# Complete the TODO blocks.

# %%
# ===== 9.1) Test perplexity =====
test_ppl = evaluate_perplexity(model, test_loader)  # will work after TODOs done
print("Test perplexity:", test_ppl)
# Out:
# Test perplexity: 1.0003448983235008

# %%
# ===== 9.2) Text generation (TODO) =====
# We will generate tokens one-by-one:
# - Start with <bos>
# - Predict next token distribution
# - Sample (or argmax)
# - Append token and continue

def sample_next_token(logits_1v: torch.Tensor, temperature: float = 1.0) -> int:
    # logits_1v: (V,) logits for next token
    # TODO:
    # 1) divide logits by temperature
    scaled_logits = logits_1v / temperature
    # 2) convert to probabilities (softmax)
    # dim=0 because the input is a 1D vector of size V
    probs = torch.softmax(scaled_logits, dim=0)
    # 3) sample an index using torch.multinomial
    # num_samples=1 returns a tensor, so we use .item() to get the integer ID
    token_id = torch.multinomial(probs, num_samples=1).item()

    return token_id

@torch.no_grad()
def generate_text(model: nn.Module, stoi: Dict[str, int], itos: List[str],
                  max_new_tokens: int = 50, temperature: float = 1.0) -> str:
    model.eval()

    bos_id = stoi[SPECIAL["BOS"]]
    eos_id = stoi[SPECIAL["EOS"]]

    # Start sequence with <bos>
    generated = [bos_id]

    for _ in range(max_new_tokens):
        # TODO:
        # 1) create input tensor x of shape (1, current_len)
        x = torch.tensor([generated], dtype=torch.long).to(device)
        # 2) logits = model(x) -> (1, current_len, V)
        logits = model(x)
        # 3) take last timestep logits: logits[0, -1, :]
        last_token_logits = logits[0, -1, :]
        # 4) sample next token id
        next_id = sample_next_token(last_token_logits, temperature)
        # 5) append; break if eos
        generated.append(next_id)
        if next_id == eos_id:
          break

    # Convert ids to tokens and return as a string
    tokens = [itos[i] for i in generated]
    return " ".join(tokens)

# Printing 3 generated sentences with 30+ tokens
count = 0
while count <= 3:
  gen_sent = generate_text(model, stoi, itos, max_new_tokens=60, temperature=1.0)
  if len(gen_sent.split()) > 30:
    print(gen_sent)
    count += 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-266/2025687365.py in <cell line: 0>()
#       6 # - Append token and continue
#       7
# ----> 8 def sample_next_token(logits_1v: torch.Tensor, temperature: float = 1.0) -> int:
#       9     # logits_1v: (V,) logits for next token
#      10     # TODO:
#
# NameError: name 'torch' is not defined

# %% [markdown]
# # What you submit for Part B
#
# In your final submission, include:
# - Your completed code for all TODO blocks
# - Your training loss plot
# - Validation perplexity per epoch (printed)
# - Final test perplexity
# - 3 generated samples (30+ tokens each) with brief comments
